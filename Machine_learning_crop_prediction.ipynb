# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset/Crop_recommendation.csv')
df.head(10)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# 5  69  37  42    23.058049  83.370118  7.073454  251.055000  rice
# 6  69  55  38    22.708838  82.639414  5.700806  271.324860  rice
# 7  94  53  40    20.277744  82.894086  5.718627  241.974195  rice
# 8  89  54  38    24.515881  83.535216  6.685346  230.446236  rice
# 9  68  58  38    23.223974  83.033227  6.336254  221.209196  rice

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df.size
# Out:
# 17600

# %%
df.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
df.label.unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
df.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)
from google.colab import files
plt.savefig('Heatmap.jpg')
files.download('Heatmap.jpg')
# Out:
# <ipython-input-13-32e7ba8e92dd>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
crops = df['label'].unique()
print(len(crops))
print(crops)
print(pd.value_counts(df['label']))
# Out:
# 22
# ['rice' 'maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans'
#  'mungbean' 'blackgram' 'lentil' 'pomegranate' 'banana' 'mango' 'grapes'
#  'watermelon' 'muskmelon' 'apple' 'orange' 'papaya' 'coconut' 'cotton'
#  'jute' 'coffee']
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %%
import matplotlib.pyplot as plt
crops=df['label'].unique()
count=pd.value_counts(df['label'])

plt.pie(count,labels=crops,autopct='%d%%')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import files

# Sample data
data = {
    'label': ['Apples','Bananas','papaya','Oranges', 'Grapes', 'Pears','watermelon','pomegrante','jute','coffee','coconut','cotton','rice','maize','chickpea','kidneybeans','pigeonpeas','mothbeans','lentil','mungbean','blackgram','Mango'],
}
df = pd.DataFrame(data)

crops = df['label'].unique()
count = pd.value_counts(df['label'])

plt.pie(count, labels=crops, autopct='%d%%')
plt.title('Crop Distribution')

# Save the pie chart as an image
plt.savefig('Piechart.jpg')

# Download the saved image
files.download('Piechart.jpg')

# %%
df.size
# Out:
# 17600

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
print(df.isnull().sum())
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('dark_background')
sns.set_palette("Set2")

for i in df.columns[:-1]:
    plt.figure(figsize=(4, 4))
    sns.histplot(data=df, x=i, kde=True, bins=20)
    plt.title(f'Visualizing {i}', size=5)
    plt.xlabel(i)
    plt.ylabel('Count')
    plt.show()

# %%
features = df[['N','P','K','temperature','humidity','ph','rainfall']]

# %%
target = df['label']
labels = df['label']

# %%
acc=[]
model = []

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(features,target,random_state=42,test_size=0.3)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
import seaborn as sns

# %%
from sklearn import metrics

# %%
import numpy

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

dt = DecisionTreeClassifier(criterion="entropy",random_state=42,max_depth=5)
dt.fit(xtrain,ytrain)
confusion_dt=confusion_matrix(ytest,dt.predict(xtest))
plt.figure(figsize=(8,8))
sns.heatmap(confusion_dt,annot=True)

predicted_values = dt.predict(xtest)
x = metrics.accuracy_score(ytest, predicted_values)
acc.append(x)
model.append('Decision Tree')
print("DecisionTrees's Accuracy is: ", x)

print(classification_report(ytest,predicted_values))
# Out:
# DecisionTrees's Accuracy is:  0.8681818181818182
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        34
#       banana       1.00      1.00      1.00        26
#    blackgram       0.57      1.00      0.72        26
#     chickpea       1.00      0.97      0.99        34
#      coconut       1.00      1.00      1.00        33
#       coffee       1.00      1.00      1.00        30
#       cotton       1.00      1.00      1.00        28
#       grapes       1.00      1.00      1.00        23
#         jute       0.71      0.94      0.81        34
#  kidneybeans       0.00      0.00      0.00        36
#       lentil       0.50      1.00      0.67        22
#        maize       1.00      1.00      1.00        26
#        mango       1.00      1.00      1.00        32
#    mothbeans       0.00      0.00      0.00        34
#     mungbean       0.97      1.00      0.98        30
# ...

# %%
import matplotlib.pyplot as plt

# Precision, Recall, F1-Score, and Accuracy values
metrics = ['Precision', 'Recall', 'F1-Score', 'Accuracy']
values = [0.83, 0.88, 0.84, 0.86]

# Create a bar graph
plt.figure(figsize=(4, 4))
plt.bar(metrics, values, color=['skyblue', 'lightcoral', 'lightgreen', 'lightblue'])
plt.xlabel('Metrics')
plt.ylabel('Peformance')

plt.ylim(0, 1.0)  # Adjust the y-axis limits if needed
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

RF = RandomForestClassifier(n_estimators=20, random_state=0)
RF.fit(xtrain, ytrain)

confusion_RF = confusion_matrix(ytest, RF.predict(xtest))
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_RF, annot=True)

print(classification_report(ytest, RF.predict(xtest)))

predicted_values = RF.predict(xtest)

x = accuracy_score(ytest, predicted_values)  # Use accuracy_score from sklearn.metrics
acc.append(x)
model.append('Random Forest')
print("RF's Accuracy is: ", x)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        34
#       banana       1.00      1.00      1.00        26
#    blackgram       1.00      1.00      1.00        26
#     chickpea       1.00      1.00      1.00        34
#      coconut       1.00      1.00      1.00        33
#       coffee       1.00      1.00      1.00        30
#       cotton       1.00      1.00      1.00        28
#       grapes       1.00      1.00      1.00        23
#         jute       0.87      1.00      0.93        34
#  kidneybeans       1.00      1.00      1.00        36
#       lentil       1.00      1.00      1.00        22
#        maize       1.00      1.00      1.00        26
#        mango       1.00      1.00      1.00        32
#    mothbeans       1.00      1.00      1.00        34
#     mungbean       1.00      1.00      1.00        30
#    muskmelon       1.00      1.00      1.00        24
# ...

# %%
import matplotlib.pyplot as plt

# Precision, Recall, F1-Score, and Accuracy values
metrics = ['Precision', 'Recall', 'F1-Score', 'Accuracy']
values = [0.99, 0.99, 0.99, 0.99]

# Create a bar graph
plt.figure(figsize=(4, 4))
plt.bar(metrics, values, color=['skyblue', 'lightcoral', 'lightgreen', 'lightblue'])
plt.xlabel('Metrics')
plt.ylabel('Performance')

plt.ylim(0, 1.0)  # Adjust the y-axis limits if needed
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

norm = MinMaxScaler().fit(xtrain)
x_train_norm = norm.transform(xtrain)
x_test_norm = norm.transform(xtest)

SVM = SVC(kernel='poly', degree=3, C=1)
SVM.fit(x_train_norm, ytrain)

predicted_values = SVM.predict(x_test_norm)
confusion_SVM = confusion_matrix(ytest, predicted_values)
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_SVM, annot=True)

x = accuracy_score(ytest, predicted_values)  # Use accuracy_score from sklearn.metrics
acc.append(x)
model.append('Support Vector Machine')
print("SVM's Accuracy is: ", x)
print(classification_report(ytest, predicted_values))
# Out:
# SVM's Accuracy is:  0.9681818181818181
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        34
#       banana       1.00      1.00      1.00        26
#    blackgram       0.93      1.00      0.96        26
#     chickpea       1.00      1.00      1.00        34
#      coconut       1.00      1.00      1.00        33
#       coffee       1.00      0.93      0.97        30
#       cotton       0.97      1.00      0.98        28
#       grapes       1.00      1.00      1.00        23
#         jute       0.73      0.97      0.84        34
#  kidneybeans       0.97      1.00      0.99        36
#       lentil       0.91      0.95      0.93        22
#        maize       1.00      0.96      0.98        26
#        mango       0.97      1.00      0.98        32
#    mothbeans       0.97      0.94      0.96        34
#     mungbean       1.00      1.00      1.00        30
#    muskmelon       1.00      1.00      1.00        24
# ...

# %%
import matplotlib.pyplot as plt

# Precision, Recall, F1-Score, and Accuracy values
metrics = ['Precision', 'Recall', 'F1-Score', 'Accuracy']
values = [0.97, 0.97, 0.97, 0.96]

# Create a bar graph
plt.figure(figsize=(4, 4))
plt.bar(metrics, values, color=['skyblue', 'lightcoral', 'lightgreen', 'lightblue'])
plt.xlabel('Metrics')
plt.ylabel('Performance')

plt.ylim(0, 1.0)  # Adjust the y-axis limits if needed
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

LogReg = LogisticRegression(random_state=2)

LogReg.fit(xtrain,ytrain)

predicted_values = LogReg.predict(xtest)
confusion_LogReg = confusion_matrix(ytest,predicted_values)
plt.figure(figsize=(8,8))
sns.heatmap(confusion_LogReg,annot = True)

x = metrics.accuracy_score(ytest, predicted_values)
acc.append(x)
model.append('Logistic Regression')
print("Logistic Regression's Accuracy is: ", x)

print(classification_report(ytest,predicted_values))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression's Accuracy is:  0.946969696969697
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        34
#       banana       0.96      1.00      0.98        26
#    blackgram       0.76      0.85      0.80        26
#     chickpea       1.00      1.00      1.00        34
#      coconut       1.00      1.00      1.00        33
#       coffee       0.97      1.00      0.98        30
# ...

# %%
import matplotlib.pyplot as plt

# Precision, Recall, F1-Score, and Accuracy values
metrics = ['Precision', 'Recall', 'F1-Score', 'Accuracy']
values = [0.95, 0.95, 0.95, 0.94]

# Create a bar graph
plt.figure(figsize=(4, 4))
plt.bar(metrics, values, color=['skyblue', 'lightcoral', 'lightgreen', 'lightblue'])
plt.xlabel('Metrics')
plt.ylabel('Performance')

plt.ylim(0, 1.0)  # Adjust the y-axis limits if needed
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(xtrain, ytrain)
y_pred = knn.predict(xtest)  # Predict the values for the test set

confusion_knn = confusion_matrix(ytest, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_knn, annot=True)
plt.xlabel("Predicted")
plt.ylabel("Actual")

print(classification_report(ytest, y_pred))

accuracy = accuracy_score(ytest, y_pred)
acc.append(accuracy)
model.append('K-Nearest Neighbour')
print("Knn's Accuracy is :",accuracy)
print(" ")
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        34
#       banana       1.00      1.00      1.00        26
#    blackgram       0.96      0.96      0.96        26
#     chickpea       1.00      1.00      1.00        34
#      coconut       1.00      1.00      1.00        33
#       coffee       1.00      0.97      0.98        30
#       cotton       0.96      0.96      0.96        28
#       grapes       1.00      1.00      1.00        23
#         jute       0.78      0.91      0.84        34
#  kidneybeans       0.97      1.00      0.99        36
#       lentil       0.88      1.00      0.94        22
#        maize       0.96      0.96      0.96        26
#        mango       1.00      1.00      1.00        32
#    mothbeans       0.97      0.91      0.94        34
#     mungbean       1.00      1.00      1.00        30
#    muskmelon       1.00      1.00      1.00        24
# ...

# %%
import matplotlib.pyplot as plt

# Precision, Recall, F1-Score, and Accuracy values
metrics = ['Precision', 'Recall', 'F1-Score', 'Accuracy']
values = [0.97, 0.97, 0.97, 0.96]

# Create a bar graph
plt.figure(figsize=(4, 4))
plt.bar(metrics, values, color=['skyblue', 'lightcoral', 'lightgreen', 'lightblue'])
plt.xlabel('Metrics')
plt.ylabel('Performance')

plt.ylim(0.8, 1.0)  # Adjust the y-axis limits if needed
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Create a Gradient Boosting Classifier
GB = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=0)

# Fit the model on the training data
GB.fit(xtrain, ytrain)

# Make predictions on the test data
predicted_values_GB = GB.predict(xtest)

# Calculate confusion matrix
confusion_GB = confusion_matrix(ytest, predicted_values_GB)

# Display the confusion matrix as a heatmap
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_GB, annot=True)

# Print classification report
print(classification_report(ytest, predicted_values_GB))

# Calculate and print accuracy
accuracy_GB = accuracy_score(ytest, predicted_values_GB)  # Use accuracy_score from sklearn.metrics
acc.append(accuracy_GB)
model.append('Gradient Boost')
print("Gradient Boosting's Accuracy is: ", accuracy_GB)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        34
#       banana       1.00      1.00      1.00        26
#    blackgram       0.96      1.00      0.98        26
#     chickpea       1.00      1.00      1.00        34
#      coconut       1.00      1.00      1.00        33
#       coffee       1.00      1.00      1.00        30
#       cotton       0.97      1.00      0.98        28
#       grapes       1.00      1.00      1.00        23
#         jute       0.85      0.97      0.90        34
#  kidneybeans       1.00      1.00      1.00        36
#       lentil       0.96      1.00      0.98        22
#        maize       1.00      0.96      0.98        26
#        mango       0.97      1.00      0.98        32
#    mothbeans       1.00      0.97      0.99        34
#     mungbean       1.00      1.00      1.00        30
#    muskmelon       1.00      1.00      1.00        24
# ...

# %%
import matplotlib.pyplot as plt

if __name__ == '__main__':
    # creating data on which bar chart will be plot
    metrics = ['Precision', 'Recall', 'F1-Score', 'Accuracy']
    values = [0.97, 0.97, 0.97, 0.96]
    # making the bar chart on the data
    plt.figure(figsize=(4, 4))

    plt.xlabel("Metrics")
    plt.ylabel("Performance")
    plt.bar(metrics, values, color=['skyblue', 'lightcoral', 'lightgreen', 'lightblue'])
    addlabels(metrics, values)
    plt.ylim(0.8, 1.0)

# %%
import matplotlib.pyplot as plt

# Function to add value labels
def addlabels(metrics, values):
    for i in range(len(metrics)):
        plt.text(i, values[i], f'{values[i]:.2f}', ha='center', va='bottom', color='black')

if __name__ == '__main__':
    # Creating data on which the bar chart will be plotted
    metrics = ['Precision', 'Recall', 'F1-Score', 'Accuracy']
    values = [0.97, 0.97, 0.97, 0.96]

    # Making the bar chart on the data
    plt.figure(figsize=(6, 4), facecolor='white')  # Set facecolor to 'white' for a white background
    plt.xlabel("Metrics")
    plt.ylabel("Performance")

    # Create the bar chart with custom x-axis limits
    plt.bar(metrics, values, color=['skyblue', 'lightcoral', 'lightgreen', 'lightblue'])
    plt.xlim(left=0.8)  # Set the x-axis lower limit to 0.8

    # Calling the function to add value labels
    addlabels(metrics, values)

    plt.ylim(0.8, 1.0)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Define the crop types and their corresponding F1-scores for DT
crop_types = ["Crop1", "Crop2", "Crop3", "Crop4", "Crop5"]
f1_scores = [0.85, 0.89, 0.91, 0.92, 0.86]  # Replace with your DT F1-scores

# Set Y-axis lower limit to 0.8
plt.ylim(0.5, 1.0)

# Define colors for the bars
colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightseagreen']

# Create a bar graph
plt.bar(crop_types, f1_scores, color=colors)

# Add labels and title
plt.xlabel("Crop Types")
plt.ylabel("F1-Score")
plt.title("Decision Tree Performance for Different Crop Types")

# Display the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the crop types and their corresponding F1-scores for DT
metrics = ["Precision","Recall","F1-Score","Accuracy"]
values = [0.97,0,97,0,97,0,96]  # Replace with your DT F1-scores

# Set Y-axis lower limit to 0.8
plt.ylim(0.5, 1.0)

# Define colors for the bars
colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightseagreen']

# Create a bar graph
plt.bar(metrics, values, color=colors)

# Add labels and title
plt.xlabel("Metrics")
plt.ylabel("Performance")


# Display the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-ca2d489e40e8> in <cell line: 14>()
#      12
#      13 # Create a bar graph
# ---> 14 plt.bar(metrics, values, color=colors)
#      15
#      16 # Add labels and title
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# ...

# %%
import matplotlib.pyplot as plt

# Function to add value labels
def addlabels(metrics, values):
    for i in range(len(metrics)):
        plt.text(i, values[i], f'{values[i]:.2f}', ha='center', va='bottom', color='black')

if __name__ == '__main__':
    # Creating data on which the bar chart will be plotted
    metrics = ['Precision', 'Recall', 'F1-Score', 'Accuracy']
    values = [0.97, 0.97, 0.97, 0.96]

    # Making the bar chart on the data
    plt.figure(figsize=(4, 4), facecolor='white')  # Set facecolor to 'white' for a white background
    plt.xlabel("Metrics")
    plt.ylabel("Performance")
    bars = plt.bar(metrics, values, color=['skyblue', 'lightcoral', 'lightgreen', 'lightblue'])

    # Calling the function to add value labels
    addlabels(metrics, values)

    plt.ylim(0.8, 1.0)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Precision, Recall, F1-Score, and Accuracy values
metrics = ['Precision', 'Recall', 'F1-Score', 'Accuracy']
values = [0.98, 0.98, 0.98, 0.98]

# Create a bar graph
plt.figure(figsize=(4, 4))
plt.bar(metrics, values, color=['skyblue', 'lightcoral', 'lightgreen', 'lightblue'])
plt.xlabel('Metrics')
plt.ylabel('Performance')
addlabels(metrics, values)
plt.ylim(0.8, 1.0)  # Adjust the y-axis limits if needed
plt.show()

# %%
model1=['Support\n Vector\n Machine','Random\n Forest','Decision\n Tree','K-Nearest\n Neighbour','Gradient\nBoost','Logistic\nRegression']
acc1 = [0.96,0.99,0.86,0.96,0.98,0.95]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=[6, 5])
plt.title('Accuracy Comparison')
plt.xlabel('Algorithm')
plt.ylabel('Accuracy')
sns.barplot(x = model1, y = acc1)
addlabels(model1, acc1)
plt.show()

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/dataset/Crop_recommendation.csv')

# Split the dataset into input features (X) and target variable (y)
X = data[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
y = data['label']

# Create a Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier
clf.fit(X, y)

def recommend_crop(input_data):
    # Create a DataFrame with the input parameters
    input_df = pd.DataFrame([input_data],
                            columns=['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'])

    # Make predictions on the input data
    crop = clf.predict(input_df)

    return crop[0]

# Example usage
input_values = [44,55,25,29.63,65.91,7.42,71.16]
recommended_crop = recommend_crop(input_values)
print("Recommended Crop:", recommended_crop)
# Out:
# Recommended Crop: blackgram

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/dataset/Crop_recommendation.csv')

# Extract the input features into the feature matrix 'X'
X = data[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]

# Create an instance of MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler to the feature matrix 'X'
scaler.fit(X)

# Perform normalization on 'X'
X_normalized = scaler.transform(X)
print(X_normalized)
# Out:
# [[0.64285714 0.26428571 0.19       ... 0.79026683 0.46626364 0.65645778]
#  [0.60714286 0.37857143 0.18       ... 0.77063285 0.54948026 0.74167459]
#  [0.42857143 0.35714286 0.195      ... 0.79397664 0.67421877 0.87571039]
#  ...
#  [0.84285714 0.2        0.125      ... 0.61788046 0.44443315 0.55007079]
#  [0.83571429 0.19285714 0.145      ... 0.44175991 0.50604494 0.38428046]
#  [0.74285714 0.09285714 0.125      ... 0.53822177 0.50931694 0.43372112]]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/dataset/Crop_recommendation.csv')

# Extract the input features into the feature matrix 'X'
X = data[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]

# Create an instance of StandardScaler
scaler = StandardScaler()

# Fit the scaler to the feature matrix 'X'
scaler.fit(X)

# Perform standardization on 'X'
X_standardized = scaler.transform(X)

# Print the standardized feature matrix 'X_standardized'
print(X_standardized)
# Out:
# [[ 1.0687974  -0.34455075 -0.1016875  ...  0.47266646  0.04330173
#    1.8103605 ]
#  [ 0.93332887  0.14061552 -0.14118477 ...  0.39705125  0.73487256
#    2.24205791]
#  [ 0.25598625  0.04964684 -0.08193887 ...  0.48695381  1.77151047
#    2.92106603]
#  ...
#  [ 1.82742114 -0.61745677 -0.35841972 ... -0.19123516 -0.13812031
#    1.27141766]
#  [ 1.80032743 -0.64777967 -0.27942519 ... -0.86951801  0.37390383
#    0.43154519]
#  [ 1.44810927 -1.07230015 -0.35841972 ... -0.49802006  0.40109573
#    0.68200518]]

# %%
import pandas as pd
from sklearn.preprocessing import KBinsDiscretizer

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/dataset/Crop_recommendation.csv')

# Extract the input features into the feature matrix 'X'
X = data[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]

# Create an instance of KBinsDiscretizer
discretizer = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='quantile')

# Fit the discretizer to the feature matrix 'X'
discretizer.fit(X)

# Perform discretization on 'X'
X_discretized = discretizer.transform(X)

# Print the discretized feature matrix 'X_discretized'
print(X_discretized)
# Out:
# [[3. 2. 3. ... 2. 2. 4.]
#  [3. 3. 3. ... 2. 3. 4.]
#  [3. 2. 3. ... 2. 4. 4.]
#  ...
#  [4. 1. 2. ... 1. 2. 4.]
#  [4. 1. 2. ... 0. 3. 3.]
#  [4. 0. 2. ... 1. 3. 3.]]
